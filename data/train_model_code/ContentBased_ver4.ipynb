# %% [markdown]
# ## LOAD DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Pandas
import pandas as pd

# Load Movies Metadata
metadata = pd.read_csv("/content/drive/MyDrive/Buom/ver4/Paper.csv", low_memory=False)

metadata.head(10)
# Out:
#    paper_id                                              title  \
# 0         1  Computers and Intractability: A Guide to the T...
# 1      2860  Substructure similarity search in graph databases
# 2      2884  Inferring AS Relationships: Dead End or Lively...
# 3      2885  Bidimensionality: new connections between FPT ...
# 4      2892  Hardness of the Undirected Edge-Disjoint Paths...
# 5      2899     Aggregate operators in probabilistic databases
# 6      2920  Multicommodity flow, well-linked terminals, an...
# 7      2953  Optimal Component Composition for Scalable Str...
# 8      2968  Constrained Bandwidth Allocation in MultiSenso...
# 9      3178  A dissimilarity-based approach for Classification
#
#                                             abstract published_year
# 0                                                 \N           1979
# 1  Advanced database systems face a great challen...           2005
# 2  Recent techniques for inferring business relat...           2005
# 3  We demonstrate a new connection between fixed-...           2005
# 4  In the Edge-Disjoint Paths problem with Conges...           2005
# 5  Though extensions to the relational data model...           2005
# 6  We study multicommodity routing problems in bo...           2005
# 7  Stream processing has become increasingly impo...           2005
# 8  Sensor networks are increasingly seen as a so-...           2005
# 9  The Nearest Neighbor classifier has shown to b...           2005

# %% [markdown]
# ## GET NEWEST PAPERS

# %%
df = metadata.copy()
df = df.query("published_year != r'\\N'")
df['published_year'] = df['published_year'].astype(int)
df = df.sort_values('published_year', ascending=False)
df[['paper_id', 'title', 'published_year']].head(20)
# Out:
#        paper_id                                              title  \
# 16038   1832722  Implicators based on binary aggregation operat...
# 19528   2735743  The Challenge of Visualizing Patient Histories...
# 6506     507928  Multi-Server Queueing Systems with Multiple Pr...
# 13439   1530576  An Ontology-Based Pattern Mining System for Ex...
# 6492     505622  A Web Services-Based Universal Approach to Het...
# 19537   2738129                       The Bunch-Active Shape Model
# 13455   1535232  Cryptanalysis of an MPEG-Video Encryption Sche...
# 19532   2736480  Fuzzy logic based multi-optimum programming in...
# 19531   2736422     Meta-Toys Workshop and Environment with Squeak
# 13457   1535531  A generic framework of user attention model an...
# 13478   1539157  Region-based Matching for Robust 3D Face Recog...
# 13479   1539158         Subspace Learning Based on Tensor Analysis
# 19555   2742128  Improving target acquisition for pointing inpu...
# 6459     501160  Optimizing Physical Design of Multidimensional...
# 13485   1540690  Fingerprint classification using fast Fourier ...
# 13492   1542512  A Probabilistic Multimodal Sensor Aggregation ...
# 6453     500178  Multi-modal Image Registration by Quantitative...
# 19510   2731720                      Animating pervasive computing
# 13498   1544884    An Information Acquiring Channel - Lip Movement
# 13502   1545048  Intensional Logic and Epistemic Independency o...
#
#        published_year
# 16038            2005
# 19528            2005
# 6506             2005
# 13439            2005
# 6492             2005
# 19537            2005
# 13455            2005
# 19532            2005
# 19531            2005
# 13457            2005
# 13478            2005
# 13479            2005
# 19555            2005
# 6459             2005
# 13485            2005
# 13492            2005
# 6453             2005
# 19510            2005
# 13498            2005
# 13502            2005

# %% [markdown]
# ## Get Papers published in a period

# %%
def papers_in_period(year_begin, year_end):
    q_papers = df.copy().loc[(df['published_year'] >= year_begin) & (df['published_year'] <= year_end)]
    return q_papers

# %%
papers = papers_in_period(2000,2001)
papers[['paper_id', 'title', 'published_year']].head(20)
# Out:
#        paper_id                                              title  \
# 22597   3453023  Persistent conversation: a dialog between rese...
# 10681   1234402  Controlling Overfitting in Classification-Tree...
# 22208   3392768           The Propel Distributed Services Platform
# 22070   3349978        S cilab to S cilab //: The O uragan project
# 22789   3471951  Mapping Database Content to XML Pages - A Meta...
# 22094   3355496       Parallel Processing for Branching Simulation
# 22681   3460446  Dynamic content acceleration: a caching soluti...
# 10611   1223590  An Adaptive Probe-Based Technique to Optimize ...
# 10783   1251779  A New Control Scheme for Combustion Processes ...
# 10488   1209448  A Review of the First Cooperative Projects in ...
# 22745   3466371    Propriétés temporelles indépendantes de l'ordre
# 10298   1189458  Modelling Security Policies in Hypermedia and ...
# 22096   3356418  Branching computation for visualization in med...
# 22599   3453398  ViDE: A Visual Data Extraction Environment for...
# 10902   1277583  Erratum Corrections to 'Modeling the Dynamic B...
# 10036   1162170                 Internal models for motion control
# 22611   3454508  Cooperative Multi-Attribute Bilateral Online N...
# 9914    1149314  Reference description of the daml+oil ontology...
# 22229   3398215  ANKON: A Multi-agent System for Information Ga...
# 10612   1223995  Performance Prediction Analysis of a Point Fea...
#
#        published_year
# 22597            2001
# 10681            2001
# 22208            2001
# 22070            2001
# 22789            2001
# 22094            2001
# 22681            2001
# 10611            2001
# 10783            2001
# 10488            2001
# 22745            2001
# 10298            2001
# 22096            2001
# 22599            2001
# 10902            2001
# 10036            2001
# 22611            2001
# 9914             2001
# 22229            2001
# 10612            2001

# %% [markdown]
# ## CONTENT-BASED RECOMMENDER

# %%
# Print plot overviews of the first 5 movies.
metadata['abstract'].head(20)
# Out:
# 0                                                    \N
# 1     Advanced database systems face a great challen...
# 2     Recent techniques for inferring business relat...
# 3     We demonstrate a new connection between fixed-...
# 4     In the Edge-Disjoint Paths problem with Conges...
# 5     Though extensions to the relational data model...
# 6     We study multicommodity routing problems in bo...
# 7     Stream processing has become increasingly impo...
# 8     Sensor networks are increasingly seen as a so-...
# 9     The Nearest Neighbor classifier has shown to b...
# 10    The WWW is a new advertising media in recent y...
# 11    The study of genome rearrangements, the evolut...
# 12    As an effective way for dimensionality reducti...
# 13    Extending the single optimized spaced seed of ...
# 14    Combinatorial optimization is often used to "p...
# 15    We show that link interferences in multihop wi...
# 16    Data design has been characterized as a proces...
# 17    Routing in wireless network is challenging bec...
# 18    Pervasive computing allows a user to access an...
# 19    Many problems that are intractable for general...
# Name: abstract, dtype: object

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
metadata['title_abstract'] = metadata.apply(lambda row: f"{row['title']} {row['abstract']}", axis=1)
metadata['title_abstract'] = metadata['title_abstract'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(metadata['title_abstract'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (23587, 49482)

# %% [markdown]
# Number of papers: 23587 \
# Number of terms: 49482

# %% [markdown]
# ### Using cosine similarity to find similar papers for a paper

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix) #not enough memory

# %%
# Save cosine sim
import numpy as np
np.save('/content/drive/MyDrive/Buom/ver4/cosine_similarity.npy', cosine_sim)

# %%
# Mapping paper_id to row number in dataframe
id_mapping = {index: i for i, index in enumerate(metadata['paper_id'].unique())}

# %%
# Function that takes in paper_id as input and outputs most similar papers
def get_recommendations(idx, cosine_sim=cosine_sim):
    # Get the pairwsie similarity scores of all papers with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the papers based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar papers
    sim_scores = sim_scores[1:11]

    # Get the paper id
    paper_ids = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return metadata['title'].iloc[paper_ids]

# %%
id_mapping
# Out:
# {1: 0,
#  2860: 1,
#  2884: 2,
#  2885: 3,
#  2892: 4,
#  2899: 5,
#  2920: 6,
#  2953: 7,
#  2968: 8,
#  3178: 9,
#  3247: 10,
#  3265: 11,
#  3449: 12,
#  3472: 13,
#  3473: 14,
#  3519: 15,
#  3533: 16,
#  3536: 17,
#  3549: 18,
#  3553: 19,
#  3556: 20,
#  3576: 21,
#  3645: 22,
#  3655: 23,
#  3666: 24,
#  3678: 25,
#  3683: 26,
#  3716: 27,
#  3826: 28,
#  3905: 29,
#  3985: 30,
#  4070: 31,
#  4080: 32,
#  4087: 33,
#  4088: 34,
#  4120: 35,
#  4203: 36,
#  4217: 37,
#  4230: 38,
#  4347: 39,
#  4380: 40,
#  4435: 41,
#  4511: 42,
#  4602: 43,
#  4603: 44,
#  4621: 45,
#  4660: 46,
#  4663: 47,
#  4673: 48,
#  4688: 49,
#  4720: 50,
#  4729: 51,
#  4736: 52,
#  4746: 53,
#  4761: 54,
#  4805: 55,
#  4808: 56,
#  4831: 57,
#  4892: 58,
#  5036: 59,
#  5043: 60,
#  5051: 61,
#  5052: 62,
#  5053: 63,
#  5066: 64,
#  5075: 65,
#  5083: 66,
#  5096: 67,
#  5149: 68,
#  5150: 69,
#  5241: 70,
#  5407: 71,
#  5421: 72,
#  5438: 73,
#  5443: 74,
#  5445: 75,
#  5446: 76,
#  5448: 77,
#  5472: 78,
#  5473: 79,
#  5485: 80,
#  5492: 81,
#  5506: 82,
#  5539: 83,
#  5570: 84,
#  5597: 85,
#  5625: 86,
#  5724: 87,
#  5796: 88,
#  5799: 89,
#  5800: 90,
#  5803: 91,
#  5804: 92,
#  5817: 93,
#  5831: 94,
#  5835: 95,
#  5836: 96,
#  5855: 97,
#  5859: 98,
#  5891: 99,
#  5923: 100,
#  5991: 101,
#  6007: 102,
#  6010: 103,
#  6044: 104,
#  6113: 105,
#  6114: 106,
#  6115: 107,
#  6122: 108,
#  6123: 109,
#  6127: 110,
#  6135: 111,
#  6145: 112,
#  6155: 113,
#  6199: 114,
#  6201: 115,
#  6205: 116,
#  6231: 117,
#  6376: 118,
#  6404: 119,
#  6412: 120,
#  6414: 121,
#  6417: 122,
#  6418: 123,
#  6420: 124,
#  6425: 125,
#  6429: 126,
#  6433: 127,
#  6462: 128,
#  6463: 129,
#  6478: 130,
#  6486: 131,
#  6499: 132,
#  6540: 133,
#  6561: 134,
#  6564: 135,
#  6685: 136,
#  6686: 137,
#  44064: 676,
#  44073: 677,
#  44077: 678,
#  44087: 679,
#  44211: 680,
#  44228: 681,
#  44231: 682,
#  44314: 683,
#  44315: 684,
#  44316: 685,
#  44317: 686,
#  44321: 687,
#  44324: 688,
#  44329: 689,
#  44331: 690,
#  44387: 691,
#  44392: 692,
#  44431: 693,
#  44432: 694,
#  44434: 695,
#  44439: 696,
#  44440: 697,
#  44447: 698,
#  44456: 699,
#  44471: 700,
#  44473: 701,
#  44474: 702,
#  44499: 703,
#  44503: 704,
#  44515: 705,
#  44520: 706,
#  44522: 707,
#  44529: 708,
#  44533: 709,
#  44541: 710,
#  44572: 711,
#  44596: 712,
#  44623: 713,
#  44661: 714,
#  45024: 715,
#  45215: 716,
#  45229: 717,
#  45231: 718,
#  45272: 719,
#  45302: 720,
#  45338: 721,
#  45363: 722,
#  45367: 723,
#  45372: 724,
#  45378: 725,
#  45427: 726,
#  45486: 727,
#  45626: 728,
#  45645: 729,
#  45658: 730,
#  45699: 731,
#  45719: 732,
#  45743: 733,
#  45755: 734,
#  45812: 735,
#  45844: 736,
#  45978: 737,
#  46003: 738,
#  46072: 739,
#  46092: 740,
#  46123: 741,
#  46146: 742,
#  46255: 743,
#  46377: 744,
#  46404: 745,
#  46458: 746,
#  46462: 747,
#  46531: 748,
#  46695: 749,
#  46780: 750,
#  46809: 751,
#  46905: 752,
#  46969: 753,
#  46971: 754,
#  47056: 755,
#  47104: 756,
#  47225: 757,
#  47253: 758,
#  47320: 759,
#  47326: 760,
#  47445: 761,
#  47446: 762,
#  47449: 763,
#  47498: 764,
#  47502: 765,
#  47504: 766,
#  47521: 767,
#  47594: 768,
#  47598: 769,
#  47603: 770,
#  47620: 771,
#  47640: 772,
#  47650: 773,
#  47651: 774,
#  47652: 775,
#  47653: 776,
#  47669: 777,
#  47679: 778,
#  47684: 779,
#  47688: 780,
#  47697: 781,
#  47777: 782,
#  47793: 783,
#  47814: 784,
#  47816: 785,
#  47818: 786,
#  47843: 787,
#  47855: 788,
#  47861: 789,
#  47877: 790,
#  47878: 791,
#  47883: 792,
#  47967: 793,
#  48184: 794,
#  48190: 795,
#  48251: 796,
#  48308: 797,
#  48321: 798,
#  48372: 799,
#  48402: 800,
#  48424: 801,
#  48432: 802,
#  48438: 803,
#  48445: 804,
#  48494: 805,
#  48536: 806,
#  48578: 807,
#  48592: 808,
#  48623: 809,
#  48637: 810,
#  48722: 811,
#  48801: 812,
#  48831: 813,
#  48838: 814,
#  48905: 815,
#  48930: 816,
#  48931: 817,
#  48940: 818,
#  48977: 819,
#  48982: 820,
#  48988: 821,
#  48991: 822,
#  48993: 823,
#  49019: 824,
#  49058: 825,
#  49070: 826,
#  49081: 827,
#  49392: 828,
#  49588: 829,
#  49606: 830,
#  49638: 831,
#  49650: 832,
#  49651: 833,
#  49702: 834,
#  49713: 835,
#  49725: 836,
#  49741: 837,
#  49746: 838,
#  49759: 839,
#  49773: 840,
#  49824: 841,
#  49835: 842,
#  49836: 843,
#  49838: 844,
#  49845: 845,
#  49869: 846,
#  49891: 847,
#  49898: 848,
#  49901: 849,
#  49942: 850,
#  49943: 851,
#  49953: 852,
#  49956: 853,
#  49960: 854,
#  49962: 855,
#  49968: 856,
#  49974: 857,
#  49985: 858,
#  49993: 859,
#  49998: 860,
#  50000: 861,
#  50001: 862,
#  50007: 863,
#  50019: 864,
#  50020: 865,
#  50024: 866,
#  50044: 867,
#  50046: 868,
#  50047: 869,
#  50049: 870,
#  50058: 871,
#  50087: 872,
#  50092: 873,
#  50094: 874,
#  50097: 875,
#  50099: 876,
#  50108: 877,
#  50113: 878,
#  50119: 879,
#  50124: 880,
#  50130: 881,
#  50140: 882,
#  50159: 883,
#  50162: 884,
#  50164: 885,
#  50185: 886,
#  50186: 887,
#  50188: 888,
#  50191: 889,
#  50204: 890,
#  50223: 891,
#  50229: 892,
#  50233: 893,
#  50234: 894,
#  50238: 895,
#  50239: 896,
#  50246: 897,
#  50249: 898,
#  50250: 899,
#  50254: 900,
#  50282: 901,
#  50299: 902,
#  50317: 903,
#  50319: 904,
#  50323: 905,
#  50326: 906,
#  50350: 907,
#  50352: 908,
#  50390: 909,
#  50395: 910,
#  50398: 911,
#  50409: 912,
#  50451: 913,
#  50452: 914,
#  50453: 915,
#  50457: 916,
#  50458: 917,
#  50465: 918,
#  50491: 919,
#  50496: 920,
#  50502: 921,
#  50503: 922,
#  50523: 923,
#  50527: 924,
#  50544: 925,
#  50551: 926,
#  50556: 927,
#  50771: 928,
#  51300: 929,
#  51555: 930,
#  51915: 931,
#  52335: 932,
#  52754: 933,
#  52786: 934,
#  52846: 935,
#  52864: 936,
#  52908: 937,
#  52928: 938,
#  52943: 939,
#  52949: 940,
#  52964: 941,
#  52996: 942,
#  53080: 943,
#  53081: 944,
#  53084: 945,
#  53104: 946,
#  53106: 947,
#  53116: 948,
#  53119: 949,
#  53133: 950,
#  53172: 951,
#  53180: 952,
#  54014: 953,
#  54100: 954,
#  54382: 955,
#  54801: 956,
#  54812: 957,
#  54837: 958,
#  54885: 959,
#  54889: 960,
#  54921: 961,
#  54927: 962,
#  54934: 963,
#  55002: 964,
#  55008: 965,
#  55012: 966,
#  55053: 967,
#  55057: 968,
#  55061: 969,
#  55089: 970,
#  55103: 971,
#  55113: 972,
#  55118: 973,
#  55131: 974,
#  55161: 975,
#  55173: 976,
#  55184: 977,
#  55217: 978,
#  55220: 979,
#  55228: 980,
#  55232: 981,
#  55257: 982,
#  55261: 983,
#  55262: 984,
#  55285: 985,
#  55290: 986,
#  55311: 987,
#  55312: 988,
#  55316: 989,
#  55349: 990,
#  55370: 991,
#  55406: 992,
#  55666: 993,
#  56067: 994,
#  56103: 995,
#  56131: 996,
#  56165: 997,
#  56167: 998,
#  56184: 999,
#  ...}

# %%
input_paper_idx = 6135
# 3338907
# 469306
# 170
# 202
get_recommendations(id_mapping[input_paper_idx])
# Out:
# 2391    A tight bound on approximating arbitrary metri...
# 2397      On approximating planar metrics by tree metrics
# 3044    Approximating min-sum k -clustering in metric ...
# 4930    On approximating arbitrary metrics by tree met...
# 3876    Approximation algorithms for the metric labeli...
# 4261    Probabilistic approximation of metric spaces a...
# 4653              The Finite Capacity Dial-A-Ride Problem
# 4506                   On Approximation Algorithms for #P
# 6171    Deterministic Polylog Approximation for Minimu...
# 6225    A Linear Programming Formulation and Approxima...
# Name: title, dtype: object
